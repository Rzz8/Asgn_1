# %%
import pandas as pd
df = pd.read_csv("Assignment1.csv")
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145490 entries, 0 to 145489
# Data columns (total 27 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145490 non-null  object
#  1   Day            145490 non-null  int64
#  2   Month          145490 non-null  int64
#  3   Location       145490 non-null  object
#  4   MinTemp        144005 non-null  float64
#  5   MaxTemp        144229 non-null  float64
#  6   Rainfall       142228 non-null  float64
#  7   Evaporation    82670 non-null   float64
#  8   Sunshine       75625 non-null   float64
#  9   WindGustDir    135163 non-null  object
#  10  WindGustSpeed  135226 non-null  float64
#  11  WindDir9am     134922 non-null  object
#  12  WindDir3pm     141262 non-null  object
#  13  WindSpeed9am   143722 non-null  float64
#  14  WindSpeed3pm   142428 non-null  float64
#  15  Humidity9am    142836 non-null  float64
#  16  Humidity3pm    140983 non-null  float64
# ...

# %%
df['RainLastWeek'].value_counts()
# Out:
# RainLastWeek
# No     110323
# Yes     31905
# Name: count, dtype: int64

# %%
df['RainToday'].value_counts()
# Out:
# RainToday
# No     110341
# Yes     31887
# Name: count, dtype: int64

# %%
df['RainTomorrow'].value_counts()
# Out:
# RainTomorrow
# No     110338
# Yes     31884
# Name: count, dtype: int64

# %%
df['ENSO'].value_counts()
# Out:
# ENSO
# Yes    10680
# yes     2485
# No       383
# .        116
# Name: count, dtype: int64

# %%
binary_map = {'Yes': 1, 'yes': 1, 'No': 0}
df['RainLastWeek'] = df['RainLastWeek'].map(binary_map)
df['RainLastWeek'].value_counts()
# Out:
# RainLastWeek
# 0.0    110323
# 1.0     31905
# Name: count, dtype: int64

# %%
df['RainToday'] = df['RainToday'].map(binary_map)
df['RainToday'].value_counts()
# Out:
# RainToday
# 0.0    110341
# 1.0     31887
# Name: count, dtype: int64

# %%
df['RainTomorrow'] = df['RainTomorrow'].map(binary_map)
df['RainTomorrow'].value_counts()
# Out:
# RainTomorrow
# 0.0    110338
# 1.0     31884
# Name: count, dtype: int64

# %%
df['ENSO'] = df['ENSO'].map(binary_map)
df['ENSO'].value_counts()
# Out:
# ENSO
# 1.0    13165
# 0.0      383
# Name: count, dtype: int64

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145490 entries, 0 to 145489
# Data columns (total 27 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145490 non-null  object
#  1   Day            145490 non-null  int64
#  2   Month          145490 non-null  int64
#  3   Location       145490 non-null  object
#  4   MinTemp        144005 non-null  float64
#  5   MaxTemp        144229 non-null  float64
#  6   Rainfall       142228 non-null  float64
#  7   Evaporation    82670 non-null   float64
#  8   Sunshine       75625 non-null   float64
#  9   WindGustDir    135163 non-null  object
#  10  WindGustSpeed  135226 non-null  float64
#  11  WindDir9am     134922 non-null  object
#  12  WindDir3pm     141262 non-null  object
#  13  WindSpeed9am   143722 non-null  float64
#  14  WindSpeed3pm   142428 non-null  float64
#  15  Humidity9am    142836 non-null  float64
#  16  Humidity3pm    140983 non-null  float64
# ...

# %%
import numpy as np
df2 = df.select_dtypes(include=[np.number])

# %%
df2.mean()
# Out:
# Day                15.712214
# Month               6.400564
# MinTemp            12.194325
# MaxTemp            23.222217
# Rainfall            2.360812
# Evaporation         5.468232
# Sunshine            7.611178
# WindGustSpeed      40.035829
# WindSpeed9am       14.043257
# WindSpeed3pm       18.662798
# Humidity9am        68.878119
# Humidity3pm        51.535320
# Pressure9am      1017.648087
# Pressure3pm      1015.253982
# Cloud9am            4.447646
# Cloud3pm            4.509859
# Temp9am            16.991064
# Temp3pm            21.684221
# RainLastWeek        0.224323
# RainToday           0.224196
# RainTomorrow        0.224185
# ENSO                0.971730
# dtype: float64

# %%
df2.median()
# Out:
# Day                16.0
# Month               6.0
# MinTemp            12.0
# MaxTemp            22.6
# Rainfall            0.0
# Evaporation         4.8
# Sunshine            8.4
# WindGustSpeed      39.0
# WindSpeed9am       13.0
# WindSpeed3pm       19.0
# Humidity9am        70.0
# Humidity3pm        52.0
# Pressure9am      1017.6
# Pressure3pm      1015.2
# Cloud9am            5.0
# Cloud3pm            5.0
# Temp9am            16.7
# Temp3pm            21.1
# RainLastWeek        0.0
# RainToday           0.0
# RainTomorrow        0.0
# ENSO                1.0
# dtype: float64

# %%
df2.mode()[0:1]
# Out:
#    Day  Month  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0    1    3.0     11.0     20.0       0.0          4.0       0.0
#
#    WindGustSpeed  WindSpeed9am  WindSpeed3pm  ...  Pressure9am  Pressure3pm  \
# 0           35.0           9.0          13.0  ...       1016.4       1015.3
#
#    Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainLastWeek  RainToday  \
# 0       7.0       7.0     17.0     20.0           0.0        0.0
#
#    RainTomorrow  ENSO
# 0           0.0   1.0
#
# [1 rows x 22 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
ax = sns.boxplot(df['Rainfall'])
plt.show()

# %%
ng = sns.distplot(df['Evaporation'])
plt.show()

# %%
ng = sns.distplot(df['Sunshine'].dropna())
plt.show()

# %%
max_sunshine_row = df[df['Sunshine'] == df['Sunshine'].max()]
location_with_max_sunshine_row = max_sunshine_row['Location'].values[0]
print(location_with_max_sunshine_row)
# Out:
# Mildura

# %%
# southly directions include S - South, SSW - South-Southwest, SSE - South-Southeast
avg_max_temp_row = df[(df['Date'].str.split('/').str[-1].astype(int) == 2016) & (df['Location'] == 'Uluru') &((df['WindGustDir'] == 'S') | (df['WindGustDir'] == 'SSW') | (df['WindGustDir'] == 'SSE'))]
avg_max_temp_row['MaxTemp'].mean()
# Out:
# 31.134426229508193

# %%
year_2017_row = df[df['Date'].str.split('/').str[-1].astype(int) == 2017]
location_rainfall_2017 = year_2017_row.groupby('Location')['Rainfall'].sum()
top_5_locations = location_rainfall_2017.nlargest(5)
print(top_5_locations)
# Out:
# Location
# Darwin          1739.0
# CoffsHarbour    1307.8
# Cairns          1256.2
# Katherine       1133.8
# Sydney           865.8
# Name: Rainfall, dtype: float64

# %%
raining_row = df[df['RainToday'] ==1]
wind_direction_counts = raining_row["WindDir3pm"].value_counts()
print(wind_direction_counts)
# Out:
# WindDir3pm
# W      2911
# WSW    2750
# S      2623
# SW     2618
# SSW    2455
# WNW    2364
# SE     2340
# SSE    2209
# NW     1892
# ESE    1482
# E      1426
# NNW    1374
# N      1326
# ENE    1165
# NE     1095
# NNE     875
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt2
plt2.scatter(df['Humidity3pm'], df['Pressure3pm'])
plt2.xlabel("Humidity at 3 pm (/%)")
plt2.ylabel("Pressure at 3 pm (hpa)")
# Out:
# Text(0, 0.5, 'Pressure at 3 pm (hpa)')

# %%
# Seems no correlation between humidity and pressure. Of course we can use some correlation metrics (such as r or R2) 
# to evaluate that but it seems we do not even need to do that. 
# Strong correlation between input features can lead to multicollinearity. If there are strong correlation, we can 
# identify and remove one of the correlated features. Or apply dimension reduction techniques (e.g., principal component analysis)

# %%
corr = df2.corr()
fig = plt.figure()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", annot_kws={"size": 5})
# Out:
# <Axes: >

# %%
# Some top positive correlations: Temp9am with MinTemp (put coefficients in these) and MaxTemp, Temp3pm with MinTemp and MaxTemp
#   Temp9am with Temp3pm, so I suggest remove Temp9am and Temp3m, as MinTemp and MaxTemp are probably more
#   useful and representative of weather of the whole day

# Some top negative correlations: Cloud9am with sunshine (-0.68), Cloud3pm with sunshine (-0.7). So probably
#   keep Sunshine and remove Cloud9am and Cloud3pm as it effectively reduce more dimensions and still keep 
#   relavent information

# %%
# Task 4 - prepare data
# Main data problems so far: 
# 1. Incorrect data type. 'ENSO' corrected
# 2. Incomplete data. Can be found in many columns but significant in some columns such as: Evaporation, Sunshine, Cloud9am, Cloud3pm, ENSO.
#    As Cloud9am and Cloud3pm are removed, we can mainly focused on working with Evaporation, Sunshine, and ENSO. 
# 3. Inconsistent data. Also seen in "ENSO", "no" and "No", "." and "NA". Easily fix.
# 4. Noisy data. 
# 5. Skewed data. Tree-based machine learning algorithms are okay with skewed data, but for other machine learning algorithms we can
#    nomarlize the data.
# 6. Date, month, day should be removed?

# %%
# Task 5 -
